# %% [markdown]
# ### Duolingo Vocabulary Retention Data Exploration
#
# Data exploration analysis on the data set that is to used in the consultancy project.

# %%
import pandas as pd

# 1. load data

df = pd.read_csv("../data/duolingo_sample.csv")
df.shape

# %%
# 2. preview data
df.head()

# %%
# 3. check data types and structure
df.info()

# %%
# 4. summary stats
df.describe()

# %%
# 5. check for missing data. this move may be done earlier.
df.isnull.sum()
